# %%
from google.colab import drive
drive.mount('/content/drive')
import zipfile
import os
from google.colab import runtime
import sys
sys.path.append('/content/drive/Othercomputers/pc/train/')
import trainer
import misc
n_cpu = os.cpu_count()
print(f"Number of CPUs available: {n_cpu}")
# !pwd
# Out:
# Mounted at /content/drive
# Number of CPUs available: 12
# /content

# %%
# Extract the Training data

zip_path = 'drive/MyDrive/lfi/dataset.zip'
extract_path = 'data'

# Ensure the destination folder exists
os.makedirs(extract_path, exist_ok=True)

# Unzip the file
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

# %%
# Weights and Biases (wandb) for tracking
# !pip install wandb
import wandb
wandb.login()
# Out:
# Collecting wandb
#   Downloading wandb-0.16.6-py3-none-any.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 36.3 MB/s eta 0:00:00
# Requirement already satisfied: Click!=8.0.0,>=7.1 in /usr/local/lib/python3.10/dist-packages (from wandb) (8.1.7)
# Collecting GitPython!=3.1.29,>=1.0.0 (from wandb)
#   Downloading GitPython-3.1.43-py3-none-any.whl (207 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 29.6 MB/s eta 0:00:00
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (2.31.0)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (5.9.5)
# Collecting sentry-sdk>=1.0.0 (from wandb)
#   Downloading sentry_sdk-1.44.1-py2.py3-none-any.whl (266 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 266.1/266.1 kB 34.3 MB/s eta 0:00:00
# Collecting docker-pycreds>=0.4.0 (from wandb)
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from wandb) (6.0.1)
# Collecting setproctitle (from wandb)
#   Downloading setproctitle-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from wandb) (67.7.2)
# Requirement already satisfied: appdirs>=1.4.3 in /usr/local/lib/python3.10/dist-packages (from wandb) (1.4.4)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.19.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (3.20.3)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
# Collecting gitdb<5,>=4.0.1 (from GitPython!=3.1.29,>=1.0.0->wandb)
#   Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 10.3 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (2024.2.2)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb)
#   Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Installing collected packages: smmap, setproctitle, sentry-sdk, docker-pycreds, gitdb, GitPython, wandb
# Successfully installed GitPython-3.1.43 docker-pycreds-0.4.0 gitdb-4.0.11 sentry-sdk-1.44.1 setproctitle-1.3.3 smmap-5.0.1 wandb-0.16.6
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#  ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %% [markdown]
# ## 1

# %%
if False:
    # Start a new wandb run to track this experiment
    wandb_project = "LfI24"

    # Actual experiment
    run_name = "bl_enhanced_1"

    run = wandb.init(
        # set the wandb project where this run will be logged
        project=wandb_project,
        name=run_name)

    log = []
    modelname = "baseline"
    dataset_path = "data/dataset"
    results_path = "drive/Othercomputers/pc/train/results/colab"
    result_model_file = f"{results_path}/{run_name}.pth"
    results_logs_file = f"{results_path}/{run_name}_log.json"

    # Number of data loader workers
    n_workers = n_cpu - 2
    if n_cpu <= 6:
        n_workers = n_cpu

    try:
        res = trainer.train_eval_model(
            model_name=modelname,
            data_dir=dataset_path,
            batch_size=256,
            epochs=100,
            momentum=0.9,
            lr=0.5,
            weight_decay=2e-05,
            useCosineAnnealingLR=True,
            warmup_epochs=5,
            warmup_lr_decay=0.01,
            label_smoothing=0.1,
            n_data_workers=n_workers,
            pin_memory=True,
            cuda_force=True,
            log=log,
            wandb_id=run.id,
            wandb_project=wandb_project,
            safe_model=True,
            safe_model_file=result_model_file)

        misc.save_to_json_robust(res, results_logs_file)

    except KeyboardInterrupt:
        print("Interrupted by user.")
        misc.save_to_json_robust(log, f"{results_path}/{run_name}_log_unfinished.json")

# %% [markdown]
# ## 2
# lr=0.01, weight_decay=1e-04

# %%
if True:
    # Start a new wandb run to track this experiment
    wandb_project = "LfI24"

    # Actual experiment
    run_name = "bl_enhanced_2"

    run = wandb.init(
        # set the wandb project where this run will be logged
        project=wandb_project,
        name=run_name)

    log = []
    modelname = "baseline"
    dataset_path = "data/dataset"
    results_path = "drive/Othercomputers/pc/train/results/colab"
    result_model_file = f"{results_path}/{run_name}.pth"
    result_model_final_file = f"{results_path}/{run_name}_final.pth"
    results_logs_file = f"{results_path}/{run_name}_log.json"

    # Number of data loader workers
    n_workers = n_cpu - 2
    if n_cpu <= 6:
        n_workers = n_cpu

    try:
        res = trainer.train_eval_model(
            model_name=modelname,
            data_dir=dataset_path,
            batch_size=256,
            epochs=35,
            momentum=0.9,
            lr=0.01,
            weight_decay=1e-04,
            useCosineAnnealingLR=True,
            warmup_epochs=5,
            warmup_lr_decay=0.01,
            label_smoothing=0.1,
            class_weights=None,
            n_data_workers=n_workers,
            pin_memory=True,
            cuda_force=True,
            log=log,
            wandb_id=run.id,
            wandb_project=wandb_project,
            safe_model=True,
            safe_model_file=result_model_file,
            safe_model_file_final=result_model_final_file)

        misc.save_to_json_robust(res, results_logs_file)

    except KeyboardInterrupt:
        print("Interrupted by user.")
        misc.save_to_json_robust(log, f"{results_path}/{run_name}_log_unfinished.json")
# Out:
# Tracking run with wandb version 0.16.6
# Run data is saved locally in <code>/content/wandb/run-20240407_003945-m2mz8wz0</code>
# Syncing run <strong><a href='https://wandb.ai/chr_te/LfI24/runs/m2mz8wz0' target="_blank">bl_enhanced_2</a></strong> to <a href='https://wandb.ai/chr_te/LfI24' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/chr_te/LfI24' target="_blank">https://wandb.ai/chr_te/LfI24</a>
#  View run at <a href='https://wandb.ai/chr_te/LfI24/runs/m2mz8wz0' target="_blank">https://wandb.ai/chr_te/LfI24/runs/m2mz8wz0</a>
# Data encoding: {'non_smile': 0, 'smile': 1}
# Finishing last run (ID:m2mz8wz0) before initializing another...
# VBox(children=(Label(value='0.002 MB of 0.002 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
#  View run <strong style="color:#cdcd00">bl_enhanced_2</strong> at: <a href='https://wandb.ai/chr_te/LfI24/runs/m2mz8wz0' target="_blank">https://wandb.ai/chr_te/LfI24/runs/m2mz8wz0</a><br/> View project at: <a href='https://wandb.ai/chr_te/LfI24' target="_blank">https://wandb.ai/chr_te/LfI24</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240407_003945-m2mz8wz0/logs</code>
# Successfully finished last run (ID:m2mz8wz0). Initializing new run:<br/>
# Tracking run with wandb version 0.16.6
# Run data is saved locally in <code>/content/wandb/run-20240407_003950-m2mz8wz0</code>
# Resuming run <strong><a href='https://wandb.ai/chr_te/LfI24/runs/m2mz8wz0' target="_blank">bl_enhanced_2</a></strong> to <a href='https://wandb.ai/chr_te/LfI24' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/chr_te/LfI24' target="_blank">https://wandb.ai/chr_te/LfI24</a>
#  View run at <a href='https://wandb.ai/chr_te/LfI24/runs/m2mz8wz0' target="_blank">https://wandb.ai/chr_te/LfI24/runs/m2mz8wz0</a>
# Epochs:   0%|          | 0/35 [00:00<?, ?it/s]
# Training:   0%|          | 0/140 [00:00<?, ?it/s]
# Validation:   0%|          | 0/30 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:156: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
# Best model's state dict saved at drive/Othercomputers/pc/train/results/colab/bl_enhanced_2.pth
# Final model saved at drive/Othercomputers/pc/train/results/colab/bl_enhanced_2_final.pth
# VBox(children=(Label(value='0.000 MB of 0.000 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁▃▄▅▆▇▇██▇██████████▇██████████████</td></tr><tr><td>duration_s</td><td>▃▃▄▆▃▂▄▆▃▄▂▄▅▃▁▅▄▅▄▆▃▆▄▇▄▄▃▇▅██▄▃▃█</td></tr><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▃▃▃▃▃▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>f1_score</td><td>▁▃▅▅▆▇▇▇▇▆▇▇█▇▇█▇███▇▇▇▇▇█▇▇▇▇▇▇██▇</td></tr><tr><td>precision</td><td>▁▆▇█▅▇▆▆▇█▇▇▆▆▆▅▇▅▆▆▇▆▆▇▆▆▆▆▆▆▆▇▆▆▆</td></tr><tr><td>recall</td><td>▁▃▄▄▆▆▇▇▆▆▆▆▇▇▇█▆█▇▇▆▇▇▆▇▇▇▇▇▇▇▆▇▇▇</td></tr><tr><td>train_loss</td><td>█▆▄▃▃▂▂▂▂▂▂▁▂▂▁▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▅▄▃▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.77377</td></tr><tr><td>duration_s</td><td>26.44242</td></tr><tr><td>epoch</td><td>35</td></tr><tr><td>f1_score</td><td>0.46809</td></tr><tr><td>precision</td><td>0.71335</td></tr><tr><td>recall</td><td>0.34832</td></tr><tr><td>train_loss</td><td>0.51605</td></tr><tr><td>val_loss</td><td>0.53906</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">bl_enhanced_2</strong> at: <a href='https://wandb.ai/chr_te/LfI24/runs/m2mz8wz0' target="_blank">https://wandb.ai/chr_te/LfI24/runs/m2mz8wz0</a><br/> View project at: <a href='https://wandb.ai/chr_te/LfI24' target="_blank">https://wandb.ai/chr_te/LfI24</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240407_003950-m2mz8wz0/logs</code>

# %% [markdown]
# ## 3

# %%
if False:
    # Start a new wandb run to track this experiment
    wandb_project = "LfI24"

    # Actual experiment
    run_name = "bl_enhanced_3"

    run = wandb.init(
        # set the wandb project where this run will be logged
        project=wandb_project,
        name=run_name)

    log = []
    modelname = "baseline"
    dataset_path = "data/dataset"
    results_path = "drive/Othercomputers/pc/train/results/colab"
    result_model_file = f"{results_path}/{run_name}.pth"
    results_logs_file = f"{results_path}/{run_name}_log.json"

    # Number of data loader workers
    n_workers = n_cpu - 2
    if n_cpu <= 6:
        n_workers = n_cpu

    try:
        res = trainer.train_eval_model(
            model_name=modelname,
            data_dir=dataset_path,
            batch_size=256,
            epochs=40,
            momentum=0.9,
            lr=0.001,
            weight_decay=1e-04,
            useCosineAnnealingLR=True,
            warmup_epochs=5,
            warmup_lr_decay=0.01,
            label_smoothing=0.1,
            n_data_workers=n_workers,
            pin_memory=True,
            cuda_force=True,
            log=log,
            wandb_id=run.id,
            wandb_project=wandb_project,
            safe_model=True,
            safe_model_file=result_model_file)

        misc.save_to_json_robust(res, results_logs_file)

    except KeyboardInterrupt:
        print("Interrupted by user.")
        misc.save_to_json_robust(log, f"{results_path}/{run_name}_log_unfinished.json")

# %% [markdown]
# ## 4 Class weighting
# In the data/preprocess.ipynb we hinted at using class weights for mitigating the imbalance of the dataset. Let's try this. As a starting point we use the values obtained in the preprocessing by more or less intuitive rule of thumb:
# Weight for non-smile class: 0.6970, weight for smile class: 1.7689
# Based upon the above example with the learning rate of 0.01. As this looked very stable
# The experiment function expects the tuple (class0, class1) = (non_smile, smile)...

# %%
if False:
    # Start a new wandb run to track this experiment
    wandb_project = "LfI24"

    # Actual experiment
    run_name = "bl_enhanced_2_cw"

    run = wandb.init(
        # set the wandb project where this run will be logged
        project=wandb_project,
        name=run_name)

    log = []
    modelname = "baseline"
    dataset_path = "data/dataset"
    results_path = "drive/Othercomputers/pc/train/results/colab"
    result_model_file = f"{results_path}/{run_name}.pth"
    result_model_final_file = f"{results_path}/{run_name}_final.pth"
    results_logs_file = f"{results_path}/{run_name}_log.json"
    class_weights = (0.6970, 1.7689)

    # Number of data loader workers
    n_workers = n_cpu - 2
    if n_cpu <= 6:
        n_workers = n_cpu

    try:
        res = trainer.train_eval_model(
            model_name=modelname,
            data_dir=dataset_path,
            batch_size=256,
            epochs=40,
            momentum=0.9,
            lr=0.01,
            weight_decay=1e-04,
            useCosineAnnealingLR=True,
            warmup_epochs=5,
            warmup_lr_decay=0.01,
            label_smoothing=0.1,
            class_weights=class_weights,
            n_data_workers=n_workers,
            pin_memory=True,
            cuda_force=True,
            log=log,
            wandb_id=run.id,
            wandb_project=wandb_project,
            safe_model=True,
            safe_model_file=result_model_file,
            safe_model_file_final=result_model_final_file)

        misc.save_to_json_robust(res, results_logs_file)

    except KeyboardInterrupt:
        print("Interrupted by user.")
        misc.save_to_json_robust(log, f"{results_path}/{run_name}_log_unfinished.json")

# %% [markdown]
# ## bl_enhanced_2_cw2
# Less aggressive weighting

# %%
if False:
    # Start a new wandb run to track this experiment
    wandb_project = "LfI24"

    # Actual experiment
    run_name = "bl_enhanced_2_cw2"

    run = wandb.init(
        # set the wandb project where this run will be logged
        project=wandb_project,
        name=run_name)

    log = []
    modelname = "baseline"
    dataset_path = "data/dataset"
    results_path = "drive/Othercomputers/pc/train/results/colab"
    result_model_file = f"{results_path}/{run_name}.pth"
    result_model_final_file = f"{results_path}/{run_name}_final.pth"
    results_logs_file = f"{results_path}/{run_name}_log.json"
    class_weights = (1.0, 1.8)

    # Number of data loader workers
    n_workers = n_cpu - 2
    if n_cpu <= 6:
        n_workers = n_cpu

    try:
        res = trainer.train_eval_model(
            model_name=modelname,
            data_dir=dataset_path,
            batch_size=256,
            epochs=30,
            momentum=0.9,
            lr=0.01,
            weight_decay=1e-04,
            useCosineAnnealingLR=True,
            warmup_epochs=5,
            warmup_lr_decay=0.01,
            label_smoothing=0.1,
            class_weights=class_weights,
            n_data_workers=n_workers,
            pin_memory=True,
            cuda_force=True,
            log=log,
            wandb_id=run.id,
            wandb_project=wandb_project,
            safe_model=True,
            safe_model_file=result_model_file,
            safe_model_file_final=result_model_final_file)

        misc.save_to_json_robust(res, results_logs_file)

    except KeyboardInterrupt:
        print("Interrupted by user.")
        misc.save_to_json_robust(log, f"{results_path}/{run_name}_log_unfinished.json")
# Out:
# Tracking run with wandb version 0.16.6
# Run data is saved locally in <code>/content/wandb/run-20240407_001612-wzu3e0jr</code>
# Syncing run <strong><a href='https://wandb.ai/chr_te/LfI24/runs/wzu3e0jr' target="_blank">bl_enhanced_2_cw2</a></strong> to <a href='https://wandb.ai/chr_te/LfI24' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/chr_te/LfI24' target="_blank">https://wandb.ai/chr_te/LfI24</a>
#  View run at <a href='https://wandb.ai/chr_te/LfI24/runs/wzu3e0jr' target="_blank">https://wandb.ai/chr_te/LfI24/runs/wzu3e0jr</a>
# Data encoding: {'non_smile': 0, 'smile': 1}
# Finishing last run (ID:wzu3e0jr) before initializing another...
# VBox(children=(Label(value='0.002 MB of 0.002 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
#  View run <strong style="color:#cdcd00">bl_enhanced_2_cw2</strong> at: <a href='https://wandb.ai/chr_te/LfI24/runs/wzu3e0jr' target="_blank">https://wandb.ai/chr_te/LfI24/runs/wzu3e0jr</a><br/> View project at: <a href='https://wandb.ai/chr_te/LfI24' target="_blank">https://wandb.ai/chr_te/LfI24</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240407_001612-wzu3e0jr/logs</code>
# Successfully finished last run (ID:wzu3e0jr). Initializing new run:<br/>
# Tracking run with wandb version 0.16.6
# Run data is saved locally in <code>/content/wandb/run-20240407_001616-wzu3e0jr</code>
# Resuming run <strong><a href='https://wandb.ai/chr_te/LfI24/runs/wzu3e0jr' target="_blank">bl_enhanced_2_cw2</a></strong> to <a href='https://wandb.ai/chr_te/LfI24' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/chr_te/LfI24' target="_blank">https://wandb.ai/chr_te/LfI24</a>
#  View run at <a href='https://wandb.ai/chr_te/LfI24/runs/wzu3e0jr' target="_blank">https://wandb.ai/chr_te/LfI24/runs/wzu3e0jr</a>
# Epochs:   0%|          | 0/30 [00:00<?, ?it/s]
# Training:   0%|          | 0/140 [00:00<?, ?it/s]
# Validation:   0%|          | 0/30 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:156: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
# Best model's state dict saved at drive/Othercomputers/pc/train/results/colab/bl_enhanced_2_cw2.pth
# Final model saved at drive/Othercomputers/pc/train/results/colab/bl_enhanced_2_cw2_final.pth
# VBox(children=(Label(value='0.000 MB of 0.000 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁▄▄▇▆▇▆█▇▃▅▇▇▆▇▅▄▇▇▇▆▆▇▆▆▆▆▇▆▆</td></tr><tr><td>duration_s</td><td>▇▅▄▂▇▂▃▄▃▄▃▅▁█▄▃▇▇▃▄▃▃▄▂▃▆▄▂▁▄</td></tr><tr><td>epoch</td><td>▁▁▁▂▂▂▂▃▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▇▇▇▇███</td></tr><tr><td>f1_score</td><td>▁▅▇▇▇██▇███▇██████████████████</td></tr><tr><td>precision</td><td>▁▄▅▇▆▆▆█▇▄▅▇▇▅▆▅▅▇▆▆▆▆▇▆▆▆▆▆▅▆</td></tr><tr><td>recall</td><td>▁▄▆▅▆▆▇▅▆█▇▆▆▇▆▇█▆▆▇▆▇▆▇▇▇▇▇▇▇</td></tr><tr><td>train_loss</td><td>█▆▅▄▃▃▂▂▂▂▂▂▂▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▅▄▃▃▂▂▁▂▄▃▁▁▂▂▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.74702</td></tr><tr><td>duration_s</td><td>25.88679</td></tr><tr><td>epoch</td><td>30</td></tr><tr><td>f1_score</td><td>0.5791</td></tr><tr><td>precision</td><td>0.552</td></tr><tr><td>recall</td><td>0.60899</td></tr><tr><td>train_loss</td><td>0.58133</td></tr><tr><td>val_loss</td><td>0.59612</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">bl_enhanced_2_cw2</strong> at: <a href='https://wandb.ai/chr_te/LfI24/runs/wzu3e0jr' target="_blank">https://wandb.ai/chr_te/LfI24/runs/wzu3e0jr</a><br/> View project at: <a href='https://wandb.ai/chr_te/LfI24' target="_blank">https://wandb.ai/chr_te/LfI24</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240407_001616-wzu3e0jr/logs</code>

# %% [markdown]
# ## 6 Baseline with class weighting

# %%
if False:
    # Start a new wandb run to track this experiment
    wandb_project = "LfI24"

    # Actual experiment
    run_name = "bl_cw"

    run = wandb.init(
        # set the wandb project where this run will be logged
        project=wandb_project,
        name=run_name)

    log = []
    modelname = "baseline"
    dataset_path = "data/dataset"
    results_path = "drive/Othercomputers/pc/train/results/colab"
    result_model_file = f"{results_path}/{run_name}.pth"
    result_model_final_file = f"{results_path}/{run_name}_final.pth"
    results_logs_file = f"{results_path}/{run_name}_log.json"
    class_weights = (0.6970, 1.7689)

    # Number of data loader workers
    n_workers = n_cpu - 2
    if n_cpu <= 6:
        n_workers = n_cpu

    try:
        res = trainer.train_eval_model(
            model_name=modelname,
            data_dir=dataset_path,
            batch_size=256,
            epochs=40,
            momentum=0.9,
            lr=0.01,
            weight_decay=1e-04,
            useCosineAnnealingLR=False,
            warmup_epochs=0,
            warmup_lr_decay=0,
            label_smoothing=0,
            class_weights=class_weights,
            n_data_workers=n_workers,
            pin_memory=True,
            cuda_force=True,
            log=log,
            wandb_id=run.id,
            wandb_project=wandb_project,
            safe_model=True,
            safe_model_file=result_model_file,
            safe_model_file_final=result_model_final_file)

        misc.save_to_json_robust(res, results_logs_file)

    except KeyboardInterrupt:
        print("Interrupted by user.")
        misc.save_to_json_robust(log, f"{results_path}/{run_name}_log_unfinished.json")
# Out:
# wandb: Currently logged in as: chr_te. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.16.6
# Run data is saved locally in <code>/content/wandb/run-20240406_234723-wfu7uqli</code>
# Syncing run <strong><a href='https://wandb.ai/chr_te/LfI24/runs/wfu7uqli' target="_blank">bl_cw</a></strong> to <a href='https://wandb.ai/chr_te/LfI24' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/chr_te/LfI24' target="_blank">https://wandb.ai/chr_te/LfI24</a>
#  View run at <a href='https://wandb.ai/chr_te/LfI24/runs/wfu7uqli' target="_blank">https://wandb.ai/chr_te/LfI24/runs/wfu7uqli</a>
# Data encoding: {'non_smile': 0, 'smile': 1}
# Downloading: "https://download.pytorch.org/models/resnet50-11ad3fa6.pth" to /root/.cache/torch/hub/checkpoints/resnet50-11ad3fa6.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 157MB/s]
# Finishing last run (ID:wfu7uqli) before initializing another...
# VBox(children=(Label(value='0.002 MB of 0.002 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
#  View run <strong style="color:#cdcd00">bl_cw</strong> at: <a href='https://wandb.ai/chr_te/LfI24/runs/wfu7uqli' target="_blank">https://wandb.ai/chr_te/LfI24/runs/wfu7uqli</a><br/> View project at: <a href='https://wandb.ai/chr_te/LfI24' target="_blank">https://wandb.ai/chr_te/LfI24</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240406_234723-wfu7uqli/logs</code>
# Successfully finished last run (ID:wfu7uqli). Initializing new run:<br/>
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011113004099999872, max=1.0…
# Tracking run with wandb version 0.16.6
# Run data is saved locally in <code>/content/wandb/run-20240406_234727-wfu7uqli</code>
# Resuming run <strong><a href='https://wandb.ai/chr_te/LfI24/runs/wfu7uqli' target="_blank">bl_cw</a></strong> to <a href='https://wandb.ai/chr_te/LfI24' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/chr_te/LfI24' target="_blank">https://wandb.ai/chr_te/LfI24</a>
#  View run at <a href='https://wandb.ai/chr_te/LfI24/runs/wfu7uqli' target="_blank">https://wandb.ai/chr_te/LfI24/runs/wfu7uqli</a>
# Epochs:   0%|          | 0/40 [00:00<?, ?it/s]
# Training:   0%|          | 0/140 [00:00<?, ?it/s]
# Validation:   0%|          | 0/30 [00:00<?, ?it/s]
# Best model's state dict saved at drive/Othercomputers/pc/train/results/colab/bl_cw.pth
# Final model saved at drive/Othercomputers/pc/train/results/colab/bl_cw_final.pth
# VBox(children=(Label(value='0.000 MB of 0.000 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▆▄▄▇▁▆▇█▃▆▇▆▆█▇█▆▅▇▇▅▆▅▆▃▆▄▇▆▄▇▅▆▆▆▅▅▄▆█</td></tr><tr><td>duration_s</td><td>█▃▁▂▂▁▂▁▁▂▁▁▂▂▁▂▂▁▁▂▂▁▁▁▂▂▂▁▂▂▃▁▁▁▂▃▃▃▃▂</td></tr><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>f1_score</td><td>▁▄▅▇▃██▂▄▇▆▆▇▆▆▅▇▆▅▄▆▆▆▇▄▆▅▇▅▅▅▆▅▆▆▅▅▅▇▃</td></tr><tr><td>precision</td><td>▄▃▃▅▁▄▅█▂▅▆▅▅▇▆▇▅▄▅▆▄▅▄▅▂▅▂▅▄▃▆▄▄▅▅▄▃▃▄█</td></tr><tr><td>recall</td><td>▃▅▆▄█▅▄▁▇▄▃▄▄▃▃▂▄▅▃▃▅▄▅▄▆▄▆▄▄▆▃▅▄▄▄▅▅▅▅▁</td></tr><tr><td>train_loss</td><td>█▅▄▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▁▁▁▂▂▂▁▂▂▂▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▄▅▅▃█▄▃▁▆▃▂▃▃▁▂▁▃▄▂▂▄▃▄▃▆▃▆▂▃▅▂▄▃▃▃▃▅▅▄▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.76249</td></tr><tr><td>duration_s</td><td>26.03509</td></tr><tr><td>epoch</td><td>40</td></tr><tr><td>f1_score</td><td>0.55029</td></tr><tr><td>precision</td><td>0.59957</td></tr><tr><td>recall</td><td>0.50849</td></tr><tr><td>train_loss</td><td>0.54048</td></tr><tr><td>val_loss</td><td>0.5153</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">bl_cw</strong> at: <a href='https://wandb.ai/chr_te/LfI24/runs/wfu7uqli' target="_blank">https://wandb.ai/chr_te/LfI24/runs/wfu7uqli</a><br/> View project at: <a href='https://wandb.ai/chr_te/LfI24' target="_blank">https://wandb.ai/chr_te/LfI24</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240406_234727-wfu7uqli/logs</code>

# %% [markdown]
# ## Dummy for testing

# %%
if False:
    # Dummy project (does not need GPU)
    # Only to test for working setup

    # Start a new wandb run to track this experiment
    wandb_project = "my-awesome-project"
    run = wandb.init(
        # set the wandb project where this run will be logged
        project=wandb_project,
        name="test_on_mini_from_colab",
    )

    log = []
    modelname = "baseline"
    mini_dataset_path = "drive/Othercomputers/pc/dataset_mini"
    result_model_file = "drive/Othercomputers/pc/train/results/colab/bl_enhanced_dummy.pth"
    results_logs_file = "drive/Othercomputers/pc/train/results/colab/bl_enhanced_dummy_log.json"

    res = trainer.train_eval_model(
        model_name=modelname,
        data_dir=mini_dataset_path,
        batch_size=2,
        epochs=4,
        momentum=0.9,
        lr=0.01,
        weight_decay=2e-05,
        useCosineAnnealingLR=True,
        warmup_epochs=2,
        warmup_lr_decay=0.01,
        label_smoothing=0.1,
        n_data_workers=4,
        pin_memory=True,
        cuda_force=False,
        log=log,
        wandb_id=run.id,
        wandb_project=wandb_project,
        safe_model=True,
        safe_model_file=result_model_file)

    misc.save_to_json_robust(res, results_logs_file)
